# %%
## Basic
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
## Excel
import os
#import xlwt
from openpyxl import load_workbook
## Data process
from scipy.interpolate import interp1d #Interpolation
from scipy.signal import savgol_filter #Smooth

# %%
def fig_pre_def(figsize_x=8, figsize_y=6,fontsize=18):
    plt.rc('font', family='Helvetica')         # 自型
    plt.rc('xtick', labelsize=fontsize)          # X軸數字的文字大小
    plt.rc('ytick', labelsize=fontsize)          # Y軸數字的文字大小
    plt.rcParams['axes.linewidth'] = 2     # 設置外框的寬度
    return plt.figure(figsize=(figsize_x,figsize_y)) 
def fig_post_def(x_ma=None, x_mi=None, y_ma=None, y_mi=None, 
                 xlim=(None,None),ylim=(None,None),
                 xlabel = None,ylabel=None):
    if x_ma or x_mi != None:
        # Edit the major and minor tick locations 設定格線 不指定將由程式自行設定
        ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(x_ma))    
        ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(x_mi))    
    if y_ma or y_mi != None:
        ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(y_ma))
        ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(y_mi))
    
    ax.xaxis.set_tick_params(which='major', size=10, width=1, direction='in', top='on')    # x軸主要格線
    ax.xaxis.set_tick_params(which='minor', size=7, width=1, direction='in', top='on')     # x軸次要格線
    ax.yaxis.set_tick_params(which='major', size=10, width=1, direction='in', right='on')   # y軸主要格線
    ax.yaxis.set_tick_params(which='minor', size=7, width=1, direction='in', right='on')   # y軸次要格線
    
    if xlim != None:
        ax.set_xlim(xlim)
    if ylim != None:
        ax.set_ylim(ylim)
    if xlabel != None:
        ax.set_xlabel(xlabel,fontsize=18)
    if ylabel != None:
        ax.set_ylabel(ylabel,fontsize=18)
    plt.legend(fontsize=18)

# %% [markdown]
# # Process the LET data

# %%
# Light_outpu_comparison

# %%
# Birks Law

# %%
def Light_output_birks_law(E):
    LO =[]
    S =2.277 # MeVee/MeV
    K_b = 33.84 # g/MeV cm^2
    LO= (E*(S))/(1+K_b*E)
    return LO
    #for i in np.arange(0,len(dE),1):
        
        #LO = np.appen(LO,)

# %%
test_array=np.arange(0,10,1)

# %%
Light_output_birks_law(test_array)
# Out:
# array([0.        , 0.06535591, 0.06630751, 0.0666309 , 0.06679378,
#        0.06689189, 0.06695746, 0.06700437, 0.0670396 , 0.06706702])

# %%
def Light_output_expoential(E)

# %%
file1 = open('response_data/EJ309_trS_response_2.0MeV_Lightoutput_Birks.txt', 'r')
LO=[]

while True:
    line = file1.readline()     # Get next line from file
    line_array = np.fromstring(line, dtype=float, sep=' ')
    
    
    if not line: # if line is empty, end of file is reached
        break
    if line_array[0]>0:
        #rint(line_array)
        LO = np.append(LO,sum(Light_output_birks_law(line_array)))


f.close()

# %%
def read_birks_file(file_name):
    file1 = open(file_name, 'r')
    LO=[]

    while True:
        line = file1.readline()     # Get next line from file
        line_array = np.fromstring(line, dtype=float, sep=' ')
    
        if not line: # if line is empty, end of file is reached
            break
        if line_array[0]>0:
            print(line_array)
            LO = np.append(LO,sum(Light_output_birks_law(line_array)))

    f.close()
    
    return LO

# %%
print(LO)
print(LO.shape)
# Out:
# [0.06573425 0.07486243 0.06335579 0.04348444 0.0625636  0.065015
#  0.06620113 0.21919715 0.1518955  0.44672265 0.06554512 0.1158382
#  0.06605317 0.22581057 0.12172213 0.10275417 0.33059433 0.06620895
#  0.42137763 0.13855953 0.17992446 0.22882766 0.29614444 0.2497577
#  0.10022667 0.39342036 0.11612975 0.12613601 0.20057038 0.12693603
#  0.05985695 0.06222078 0.06291727 0.11482048 0.14397853 0.06241362
#  0.06407913 0.12044208 0.26539221 0.19699749 0.44652215 0.18688897
#  0.33983373 0.11131656 0.41117762 0.06565603 0.21436767 0.06603952
#  0.27503253 0.0653651  0.20875153 0.0637875  0.09336618 0.35838292
#  0.29441675 0.19820167 0.06417184 0.13771539]
# (58,)

# %% [markdown]
# # Read the Geant4 simulation data

# %%
response_temp=[]
detected_counts = []
round_number = 2   # round the number two 0.01 unit
new_X= np.linspace(0, 10, num=1001, endpoint=True) # interpolation 
simulation_response = new_X[:,np.newaxis]
for i in np.arange(0.3,15.1,0.1):
    print(str(np.round(i,1)))
    response_temp=np.loadtxt("response_data/1113_EJ309_neutron_trS_response_"+str(np.round(i,1))+"MeV_Lightoutput_runtotal.txt") #Read txt file
    #
    print(len(response_temp))
    detected_counts=np.append(detected_counts,len(response_temp))
    #
    
    
    
    response_temp_binned_round=np.round(response_temp,round_number) #Set unit to 0.01MeVee
    response_temp_binned, response_temp_binned_counts = np.unique(response_temp_binned_round, return_counts=True) #counts the frequency
    interpolation_func = interp1d(response_temp_binned, response_temp_binned_counts ,fill_value="extrapolate") #interpolation
    res_counts=interpolation_func(new_X)
    res_counts[res_counts<0.0001]=0 # eliminate the number under zero
    simulation_response= np.column_stack((simulation_response,res_counts[:,np.newaxis]/100000))
    plt.plot(simulation_response[:,0],simulation_response[:,-1])
    plt.yscale("log")
print(simulation_response)
# Out:
# 0.3
# 88061
# 0.4
# 86702
# 0.5
# 84903
# 0.6
# 83863
# 0.7
# 82447
# 0.8
# 80459
# 0.9
# 80014
# 1.0
# 77757
# 1.1
# 77047
# 1.2
# 76034
# 1.3
# 74549
# 1.4
# 73179
# 1.5
# 72695
# 1.6
# 71177
# 1.7
# 70647
# 1.8
# 69117
# 1.9
# 68060
# 2.0
# 67746
# 2.1
# 66679
# 2.2
# 66376
# 2.3
# 65528
# 2.4
# 65068
# 2.5
# 63995
# 2.6
# 62799
# 2.7
# 61937
# 2.8
# 60819
# 2.9
# 59663
# 3.0
# 60039
# 3.1
# 58847
# 3.2
# 57979
# 3.3
# 57154
# 3.4
# 56180
# 3.5
# 55433
# 3.6
# 55260
# 3.7
# 54941
# 3.8
# 54282
# 3.9
# 54047
# 4.0
# 53500
# 4.1
# 53035
# 4.2
# 52196
# 4.3
# 51684
# 4.4
# 51656
# 4.5
# 51246
# 4.6
# 51095
# 4.7
# 50465
# 4.8
# 49850
# 4.9
# 49890
# 5.0
# 49656
# 5.1
# 48910
# 5.2
# 48961
# 5.3
# 48234
# 5.4
# 48192
# 5.5
# 47528
# 5.6
# 46863
# 5.7
# 46592
# 5.8
# 46013
# 5.9
# 45883
# 6.0
# 45584
# 6.1
# 45126
# 6.2
# 45089
# 6.3
# 44420
# 6.4
# 44338
# 6.5
# 43611
# 6.6
# 43664
# 6.7
# 43020
# 6.8
# 42556
# 6.9
# 41911
# 7.0
# 41734
# 7.1
# 41826
# 7.2
# 40844
# 7.3
# 40968
# 7.4
# 40440
# 7.5
# 40020
# 7.6
# 39542
# 7.7
# 38856
# 7.8
# 38851
# 7.9
# 38354
# 8.0
# 38479
# 8.1
# 38291
# 8.2
# 38637
# 8.3
# 37490
# 8.4
# 36997
# 8.5
# 36280
# 8.6
# 36339
# 8.7
# 36101
# 8.8
# 35800
# 8.9
# 35459
# 9.0
# 35222
# 9.1
# 34663
# 9.2
# 34169
# 9.3
# 34006
# 9.4
# 34040
# 9.5
# 34000
# 9.6
# 33716
# 9.7
# 33620
# 9.8
# 33248
# 9.9
# 33271
# 10.0
# 33063
# 10.1
# 32642
# 10.2
# 32590
# 10.3
# 32627
# 10.4
# 32167
# 10.5
# 32269
# 10.6
# 32349
# 10.7
# 32275
# 10.8
# 31842
# 10.9
# 31843
# 11.0
# 31504
# 11.1
# 31369
# 11.2
# 31368
# 11.3
# 31239
# 11.4
# 30627
# 11.5
# 30556
# 11.6
# 30447
# 11.7
# 30099
# 11.8
# 30435
# 11.9
# 29668
# 12.0
# 29849
# 12.1
# 29623
# 12.2
# 29484
# 12.3
# 29548
# 12.4
# 28967
# 12.5
# 29125
# 12.6
# 28875
# 12.7
# 28595
# 12.8
# 28272
# 12.9
# 28182
# 13.0
# 27942
# 13.1
# 28075
# 13.2
# 27922
# 13.3
# 27851
# 13.4
# 27731
# 13.5
# 27698
# 13.6
# 27662
# 13.7
# 27327
# 13.8
# 27721
# 13.9
# 27224
# 14.0
# 27439
# 14.1
# 26962
# 14.2
# 26976
# 14.3
# 26644
# 14.4
# 26713
# 14.5
# 26295
# 14.6
# 26614
# 14.7
# 26333
# 14.8
# 26259
# 14.9
# 26120
# 15.0
# 26015
# [[0.0000e+00 3.6060e-02 3.0430e-02 ... 3.1100e-03 3.2200e-03 2.8400e-03]
#  [1.0000e-02 9.4200e-02 5.8480e-02 ... 5.0000e-03 4.7300e-03 4.5700e-03]
#  [2.0000e-02 2.8838e-01 9.2650e-02 ... 3.8700e-03 3.7800e-03 3.7000e-03]
#  ...
#  [9.9800e+00 0.0000e+00 0.0000e+00 ... 1.0000e-05 1.0000e-05 1.0000e-05]
#  [9.9900e+00 0.0000e+00 0.0000e+00 ... 1.0000e-05 1.0000e-05 1.0000e-05]
#  [1.0000e+01 0.0000e+00 0.0000e+00 ... 1.0000e-05 1.0000e-05 1.0000e-05]]

# %%
print(simulation_response.shape)
# Out:
# (1001, 149)

# %%
plt.plot(simulation_response[:,0],simulation_response[:,30])
plt.yscale("log")

# %%
E_i =np.arange(0.1,10,0.1)
ER = (1/E_i)*((ER_parameters_publication[0]*E_i)**2+(ER_parameters_publication[1]**2)*E_i+ER_parameters_publication[2]**2 )**0.5
ER_delta_E = ((ER_parameters_publication[0]*E_i)**2+(ER_parameters_publication[1]**2)*E_i+ER_parameters_publication[2]**2 )**0.5
ER_sigma = ER_delta_E/2.355

GEB_FWHM = ER_parameters_publication[0]+ER_parameters_publication[1]*((E_i+ER_parameters_publication[2]*E_i**2)**0.5)
#GEB_FWHM = (1/E_i)*ER_parameters_publication[0]+ER_parameters_publication[1]*((E_i+ER_parameters_publication[2]*E_i**2)**0.5)
GEB_sigma = GEB_FWHM/2.355
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1f12f62d51d0> in <module>
#       8 GEB_sigma = GEB_FWHM/2.355
#       9
# ---> 10 print(FWHM)
#
# NameError: name 'FWHM' is not defined

# %%
plt.plot(E_i,ER_sigma)
plt.plot(E_i,GEB_sigma)

# %%
plt.plot(E_i,ER)
#plt.plot(E_i,GEB_FWHM)
plt.ylim(0,0.45)
# Out:
# (0.0, 0.45)

# %%
def gaussian(x, A,x0,sigma):
    return A * np.exp(-(x - x0) ** 2 / (2* sigma ** 2))

def ER_function_improve(x,LO,A,a,b,c):
    Gaussian_distribution = np.zeros(len(x))
    for LO_i, A_i in zip(LO,A):
        delta_E = ((a**2)*(LO_i**2)+((b**2)*LO_i)+c**2)**0.5
        sigma_ER = delta_E/2.355
        Gaussian_distribution_temp = gaussian(x,1,LO_i,sigma_ER)
        G_sum =sum(Gaussian_distribution_temp)
        if G_sum <= 1:
            G_sum =1
        Gaussian_distribution      += A_i*Gaussian_distribution_temp/G_sum
    return Gaussian_distribution

# %%
# energy reslution function parameters
ER_parameters_publication = [0.113, 0.065, 0.06]
ER_parameters_fitting = np.loadtxt('../../Lightoutput_calibration/output/20220208_ER_calibration.txt')[0:3]
print(ER_parameters_fitting)
# Out:
# [0.08227708 0.06849229 0.05717636]

# %%
fig_pre_def()
fig = plt.figure(figsize=(8,4))        # 圖片大小
ax = fig.add_subplot(1, 1, 1)          # 產生1x1格圖片、在第一格

a=ER_parameters_publication[0]
b=ER_parameters_publication[1]
c=ER_parameters_publication[2]

E_1 =1
delta_E = (a**2*E_1**2+((b**2)*E_1)+c**2)**0.5
sigma_ER = delta_E/2.355
ER_output_1 = gaussian(simulation_response[:,0],10,E_1,sigma_ER)
plt.plot(simulation_response[:,0],ER_output_1,'b',label='1 MeVee')

E_2 =5
delta_E = (a**2*E_2**2+((b**2)*E_2)+c**2)**0.5
sigma_ER = delta_E/2.355
ER_output_2 = gaussian(simulation_response[:,0],10,E_2,sigma_ER)

plt.plot(simulation_response[:,0],ER_output_2,'r',label='5 MeVee')

fig_post_def(xlim=(0,8),ylim=(0,12))

# %%
fig_pre_def()
fig = plt.figure(figsize=(8,4))        # 圖片大小
ax = fig.add_subplot(1, 1, 1)          # 產生1x1格圖片、在第一格

a=ER_parameters_publication[0]
b=ER_parameters_publication[1]
c=ER_parameters_publication[2]

E_1 =1
delta_E = (a**2*E_1**2+((b**2)*E_1)+c**2)**0.5
sigma_ER = delta_E/2.355
ER_output_1 = gaussian(simulation_response[:,0],1,E_1,sigma_ER)

plt.plot(simulation_response[:,0],10*ER_output_1/sum(ER_output_1),'b',label='1 MeVee')

E_2 =5
delta_E = (a**2*E_2**2+((b**2)*E_2)+c**2)**0.5
sigma_ER = delta_E/2.355
ER_output_2 = gaussian(simulation_response[:,0],1,E_2,sigma_ER)

plt.plot(simulation_response[:,0],10*ER_output_2/sum(ER_output_2),'r',label='5 MeVee')

fig_post_def(xlim=(0,8),ylim=(0,1))

# %% [raw]
# a=ER_parameters_publication[0]
# b=ER_parameters_publication[1]
# c=ER_parameters_publication[2]
#
#
# for E_i in np.arange(0.5,10,1):
#     #print(E_i)
#     delta_E = (a**2*E_i**2+((b**2)*E_i)+c**2)**0.5
#     sigma_ER = delta_E/2.355
#     goutput = gaussian(simulation_response[:,0],10,E_i,sigma_ER)
#
#     GEB_FWHM = a+b*((E_i+c*E_i**2)**0.5)
#     #print(GEB_FWHM)
#     GEB_output = gaussian(simulation_response[:,0],10,E_i,GEB_FWHM/2.355)
#     plt.plot(simulation_response[:,0],goutput,'b')
#     plt.plot(simulation_response[:,0],GEB_output,'r')

# %%
Neutron_response =  np.linspace(0, 10, num=10001, endpoint=True)[:,np.newaxis] # setup the lightoutput
Energy_axis      =  np.linspace(0, 10, num=1001, endpoint=True) # set the 

for i in np.arange(1,len(simulation_response[0,:]),1):
    #print(i)
    neutron_response_final=[]
    response_temp =[]
    response_temp = ER_function_improve(simulation_response[:,0],
                                        simulation_response[:,0],
                                        simulation_response[:,i],
                                        ER_parameters_publication[0],
                                        ER_parameters_publication[1],
                                        ER_parameters_publication[2])
    
    response_interpolation_func = interp1d(Energy_axis, response_temp ,fill_value="linear")
    neutron_response_final      = response_interpolation_func(Neutron_response[:,0])
    
    neutron_response_final[neutron_response_final<0] =0
    
    Neutron_response = np.column_stack((Neutron_response,(neutron_response_final/neutron_response_final.sum())[:,np.newaxis]))
    plt.plot(Neutron_response[:,0],Neutron_response[:,-1])

# %%
for i in np.arange(1,len(simulation_response[0,:]),1):
    plt.plot(Neutron_response[:,0],Neutron_response[:,i]*100)
plt.ylim(0,0.1)
# Out:
# (0.0, 0.1)

# %%
Neutron_response[Neutron_response<0.00001] =0
for i in np.arange(1,len(simulation_response[0,:]),1):
    plt.plot(Neutron_response[:,0],Neutron_response[:,i]*100)
    plt.yscale("log")
#plt.ylim(100,300000)
#plt.ylim(0.0001,10)

# %%
#plt.plot(simulation_response[:,0],simulation_response[:,30])
#no.1->0.3MeV no.11-> 1.3 no.46->4.8
energy_response = 5 # MeV
no_of_energy = int((energy_response-0.2)*10)
plt.plot(Neutron_response[:,0],Neutron_response[:,no_of_energy]*100)
plt.yscale("log")
#plt.ylim(0.0001,1)
plt.xlim(0,2.5)
# Out:
# (0.0, 2.5)

# %%
fig_pre_def()
fig = plt.figure(figsize=(10,6))        # 圖片大小
ax = fig.add_subplot(1, 1, 1)          # 產生1x1格圖片、在第一格

for i in np.arange(0.5,5.5,0.5):
    no_of_energy = int((i-0.2)*10)
    plt.plot(Neutron_response[20:,0],Neutron_response[20:,no_of_energy]*100,label =str(i)+' MeV')

fig_post_def(xlim=(0,3),ylim=(0.002,2))
plt.yscale("log")

# %%
fig_pre_def()
fig = plt.figure(figsize=(10,6))        # 圖片大小
ax = fig.add_subplot(1, 1, 1)          # 產生1x1格圖片、在第一格

for i in np.arange(0.5,5.5,0.5):
    no_of_energy = int((i-0.2)*10)
    plt.plot(Neutron_response[20:,0],Neutron_response[20:,no_of_energy]*100,label =str(i)+' MeV')

plt.plot([0.125, 0.125], [0.001, 2],'--r', marker = 'o',label='Threshold')
fig_post_def(xlim=(0,3),ylim=(0.001,2),xlabel ='L.O. (MeVee)',ylabel = 'relative intensity')
plt.yscale("log")

# %% [markdown]
# # efficiency

# %%
print(Neutron_response.shape)
# Out:
# (10001, 149)

# %%
Threshold_channel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7bb771de6a7f> in <module>
# ----> 1 Threshold_channel
#
# NameError: name 'Threshold_channel' is not defined

# %%
Threshold = 0.125 # MeVee
Threshold_channel = Threshold * 1000

neutron_efficiency_threshold = []

for i in np.arange(1,len(Neutron_response[0,:]),1): #column 0 is the x-axis MeVee

    number_of_neutron_inject = detected_counts[i-1]
    simulated_neutron = 100000

    area_under_response =  sum(Neutron_response[:,i])
    area_under_response_with_threshold = sum(Neutron_response[int(Threshold_channel):,i])
    efficiency_threshold = (number_of_neutron_inject/simulated_neutron)*(area_under_response_with_threshold/area_under_response)
    print('No.',i,'Energy: ', round(i/10+0.2,1),'Number of neutron inject' ,number_of_neutron_inject,'efficiency' ,efficiency_threshold)
   
    temp = np.array((np.round(i/10+0.2,1),efficiency_threshold))

    if i==1:
        neutron_efficiency_threshold = temp.copy()
    else:
        neutron_efficiency_threshold = np.vstack((neutron_efficiency_threshold,temp))
    #neutron_efficiency_threshold = np.append(neutron_efficiency_threshold, efficiency_threshold)
# Out:
# No. 1 Energy:  0.3 Number of neutron inject 88061.0 efficiency 6.740970063116033e-05
# No. 2 Energy:  0.4 Number of neutron inject 86702.0 efficiency 0.0006944001755858724
# No. 3 Energy:  0.5 Number of neutron inject 84903.0 efficiency 0.004433990152813066
# No. 4 Energy:  0.6 Number of neutron inject 83863.0 efficiency 0.020950652486413947
# No. 5 Energy:  0.7 Number of neutron inject 82447.0 efficiency 0.06691085567109517
# No. 6 Energy:  0.8 Number of neutron inject 80459.0 efficiency 0.15247137210398712
# No. 7 Energy:  0.9 Number of neutron inject 80014.0 efficiency 0.2685641422341878
# No. 8 Energy:  1.0 Number of neutron inject 77757.0 efficiency 0.35386975149413785
# No. 9 Energy:  1.1 Number of neutron inject 77047.0 efficiency 0.42120825768535874
# No. 10 Energy:  1.2 Number of neutron inject 76034.0 efficiency 0.46518602140541127
# No. 11 Energy:  1.3 Number of neutron inject 74549.0 efficiency 0.4999697015082874
# No. 12 Energy:  1.4 Number of neutron inject 73179.0 efficiency 0.5089628626246122
# No. 13 Energy:  1.5 Number of neutron inject 72695.0 efficiency 0.5256546264074262
# No. 14 Energy:  1.6 Number of neutron inject 71177.0 efficiency 0.5280051462744164
# No. 15 Energy:  1.7 Number of neutron inject 70647.0 efficiency 0.5362220161012969
# No. 16 Energy:  1.8 Number of neutron inject 69117.0 efficiency 0.5333772678584119
# No. 17 Energy:  1.9 Number of neutron inject 68060.0 efficiency 0.5368728044970223
# No. 18 Energy:  2.0 Number of neutron inject 67746.0 efficiency 0.5371706510180622
# No. 19 Energy:  2.1 Number of neutron inject 66679.0 efficiency 0.5351831945205943
# No. 20 Energy:  2.2 Number of neutron inject 66376.0 efficiency 0.5393803051046941
# No. 21 Energy:  2.3 Number of neutron inject 65528.0 efficiency 0.5366883233602185
# No. 22 Energy:  2.4 Number of neutron inject 65068.0 efficiency 0.5356756357150039
# No. 23 Energy:  2.5 Number of neutron inject 63995.0 efficiency 0.5290229918543936
# No. 24 Energy:  2.6 Number of neutron inject 62799.0 efficiency 0.5246033791739925
# No. 25 Energy:  2.7 Number of neutron inject 61937.0 efficiency 0.5201824173433015
# No. 26 Energy:  2.8 Number of neutron inject 60819.0 efficiency 0.5113412067374719
# No. 27 Energy:  2.9 Number of neutron inject 59663.0 efficiency 0.5063859614811402
# No. 28 Energy:  3.0 Number of neutron inject 60039.0 efficiency 0.5127993474512266
# No. 29 Energy:  3.1 Number of neutron inject 58847.0 efficiency 0.5048327634317602
# No. 30 Energy:  3.2 Number of neutron inject 57979.0 efficiency 0.4990749382610946
# No. 31 Energy:  3.3 Number of neutron inject 57154.0 efficiency 0.49868492628119926
# No. 32 Energy:  3.4 Number of neutron inject 56180.0 efficiency 0.4831757283444521
# No. 33 Energy:  3.5 Number of neutron inject 55433.0 efficiency 0.4794977811527988
# No. 34 Energy:  3.6 Number of neutron inject 55260.0 efficiency 0.4784014851890617
# No. 35 Energy:  3.7 Number of neutron inject 54941.0 efficiency 0.4786712222356405
# No. 36 Energy:  3.8 Number of neutron inject 54282.0 efficiency 0.47301759740516064
# No. 37 Energy:  3.9 Number of neutron inject 54047.0 efficiency 0.47458562489745454
# No. 38 Energy:  4.0 Number of neutron inject 53500.0 efficiency 0.4713735946248921
# No. 39 Energy:  4.1 Number of neutron inject 53035.0 efficiency 0.4682725912268862
# No. 40 Energy:  4.2 Number of neutron inject 52196.0 efficiency 0.4618267201212905
# No. 41 Energy:  4.3 Number of neutron inject 51684.0 efficiency 0.46007761013881804
# No. 42 Energy:  4.4 Number of neutron inject 51656.0 efficiency 0.46219070996216677
# No. 43 Energy:  4.5 Number of neutron inject 51246.0 efficiency 0.4577322306006577
# No. 44 Energy:  4.6 Number of neutron inject 51095.0 efficiency 0.45812978899134255
# No. 45 Energy:  4.7 Number of neutron inject 50465.0 efficiency 0.4530538070492073
# No. 46 Energy:  4.8 Number of neutron inject 49850.0 efficiency 0.44720296147413857
# No. 47 Energy:  4.9 Number of neutron inject 49890.0 efficiency 0.44546467632552406
# No. 48 Energy:  5.0 Number of neutron inject 49656.0 efficiency 0.43921862710544607
# No. 49 Energy:  5.1 Number of neutron inject 48910.0 efficiency 0.4331076613268363
# No. 50 Energy:  5.2 Number of neutron inject 48961.0 efficiency 0.4319762264201619
# No. 51 Energy:  5.3 Number of neutron inject 48234.0 efficiency 0.42485376236541145
# No. 52 Energy:  5.4 Number of neutron inject 48192.0 efficiency 0.42191381921706816
# No. 53 Energy:  5.5 Number of neutron inject 47528.0 efficiency 0.4179487095542169
# No. 54 Energy:  5.6 Number of neutron inject 46863.0 efficiency 0.4140920041972634
# No. 55 Energy:  5.7 Number of neutron inject 46592.0 efficiency 0.41172403665638235
# No. 56 Energy:  5.8 Number of neutron inject 46013.0 efficiency 0.40641832433305475
# No. 57 Energy:  5.9 Number of neutron inject 45883.0 efficiency 0.40579092991052185
# No. 58 Energy:  6.0 Number of neutron inject 45584.0 efficiency 0.4035404724571703
# No. 59 Energy:  6.1 Number of neutron inject 45126.0 efficiency 0.40132775249314157
# No. 60 Energy:  6.2 Number of neutron inject 45089.0 efficiency 0.4026307417411768
# No. 61 Energy:  6.3 Number of neutron inject 44420.0 efficiency 0.3932377789507162
# No. 62 Energy:  6.4 Number of neutron inject 44338.0 efficiency 0.39660981076182017
# No. 63 Energy:  6.5 Number of neutron inject 43611.0 efficiency 0.39403528235270646
# No. 64 Energy:  6.6 Number of neutron inject 43664.0 efficiency 0.39665408550241743
# No. 65 Energy:  6.7 Number of neutron inject 43020.0 efficiency 0.3910554031396895
# No. 66 Energy:  6.8 Number of neutron inject 42556.0 efficiency 0.3887821580737756
# No. 67 Energy:  6.9 Number of neutron inject 41911.0 efficiency 0.38253629791265353
# No. 68 Energy:  7.0 Number of neutron inject 41734.0 efficiency 0.38276084656785947
# No. 69 Energy:  7.1 Number of neutron inject 41826.0 efficiency 0.3827682469579085
# No. 70 Energy:  7.2 Number of neutron inject 40844.0 efficiency 0.37410982745589827
# No. 71 Energy:  7.3 Number of neutron inject 40968.0 efficiency 0.37428467650531216
# No. 72 Energy:  7.4 Number of neutron inject 40440.0 efficiency 0.36896125932200075
# No. 73 Energy:  7.5 Number of neutron inject 40020.0 efficiency 0.3663006130152569
# No. 74 Energy:  7.6 Number of neutron inject 39542.0 efficiency 0.36253903113732
# No. 75 Energy:  7.7 Number of neutron inject 38856.0 efficiency 0.356774171642452
# No. 76 Energy:  7.8 Number of neutron inject 38851.0 efficiency 0.35672792336063636
# No. 77 Energy:  7.9 Number of neutron inject 38354.0 efficiency 0.3532374153775821
# No. 78 Energy:  8.0 Number of neutron inject 38479.0 efficiency 0.35375046083211953
# No. 79 Energy:  8.1 Number of neutron inject 38291.0 efficiency 0.35235460193553503
# No. 80 Energy:  8.2 Number of neutron inject 38637.0 efficiency 0.3563454784348643
# No. 81 Energy:  8.3 Number of neutron inject 37490.0 efficiency 0.3467636470523473
# No. 82 Energy:  8.4 Number of neutron inject 36997.0 efficiency 0.3434371177332398
# No. 83 Energy:  8.5 Number of neutron inject 36280.0 efficiency 0.33703579653454546
# No. 84 Energy:  8.6 Number of neutron inject 36339.0 efficiency 0.3369267882392565
# No. 85 Energy:  8.7 Number of neutron inject 36101.0 efficiency 0.3341581697701749
# No. 86 Energy:  8.8 Number of neutron inject 35800.0 efficiency 0.3314702927284017
# No. 87 Energy:  8.9 Number of neutron inject 35459.0 efficiency 0.3284004516173754
# No. 88 Energy:  9.0 Number of neutron inject 35222.0 efficiency 0.3277125985837818
# No. 89 Energy:  9.1 Number of neutron inject 34663.0 efficiency 0.32198328845532376
# No. 90 Energy:  9.2 Number of neutron inject 34169.0 efficiency 0.3177658524896263
# No. 91 Energy:  9.3 Number of neutron inject 34006.0 efficiency 0.31554538587454806
# No. 92 Energy:  9.4 Number of neutron inject 34040.0 efficiency 0.3167547670930783
# No. 93 Energy:  9.5 Number of neutron inject 34000.0 efficiency 0.3165091197451731
# No. 94 Energy:  9.6 Number of neutron inject 33716.0 efficiency 0.31336946699743357
# No. 95 Energy:  9.7 Number of neutron inject 33620.0 efficiency 0.31278484826845565
# No. 96 Energy:  9.8 Number of neutron inject 33248.0 efficiency 0.3091357478886882
# No. 97 Energy:  9.9 Number of neutron inject 33271.0 efficiency 0.30964033617324954
# No. 98 Energy:  10.0 Number of neutron inject 33063.0 efficiency 0.3083479711932282
# No. 99 Energy:  10.1 Number of neutron inject 32642.0 efficiency 0.3040012322375861
# No. 100 Energy:  10.2 Number of neutron inject 32590.0 efficiency 0.3009903299944701
# No. 101 Energy:  10.3 Number of neutron inject 32627.0 efficiency 0.30175218870614534
# No. 102 Energy:  10.4 Number of neutron inject 32167.0 efficiency 0.2970242883815804
# No. 103 Energy:  10.5 Number of neutron inject 32269.0 efficiency 0.29597643744267793
# No. 104 Energy:  10.6 Number of neutron inject 32349.0 efficiency 0.29628494612382755
# No. 105 Energy:  10.7 Number of neutron inject 32275.0 efficiency 0.2948422730364544
# No. 106 Energy:  10.8 Number of neutron inject 31842.0 efficiency 0.29042168846638194
# No. 107 Energy:  10.9 Number of neutron inject 31843.0 efficiency 0.2902250143604806
# No. 108 Energy:  11.0 Number of neutron inject 31504.0 efficiency 0.2862392089241811
# No. 109 Energy:  11.1 Number of neutron inject 31369.0 efficiency 0.2856397743947448
# No. 110 Energy:  11.2 Number of neutron inject 31368.0 efficiency 0.28510099205231637
# No. 111 Energy:  11.3 Number of neutron inject 31239.0 efficiency 0.2848478505865566
# No. 112 Energy:  11.4 Number of neutron inject 30627.0 efficiency 0.2781434302480306
# No. 113 Energy:  11.5 Number of neutron inject 30556.0 efficiency 0.2773182040979254
# No. 114 Energy:  11.6 Number of neutron inject 30447.0 efficiency 0.27637399439890115
# No. 115 Energy:  11.7 Number of neutron inject 30099.0 efficiency 0.273031786338505
# No. 116 Energy:  11.8 Number of neutron inject 30435.0 efficiency 0.27544478391719873
# No. 117 Energy:  11.9 Number of neutron inject 29668.0 efficiency 0.26816794164817603
# No. 118 Energy:  12.0 Number of neutron inject 29849.0 efficiency 0.26980655286178135
# No. 119 Energy:  12.1 Number of neutron inject 29623.0 efficiency 0.2671839859779119
# No. 120 Energy:  12.2 Number of neutron inject 29484.0 efficiency 0.26546428850956744
# No. 121 Energy:  12.3 Number of neutron inject 29548.0 efficiency 0.2666526770869183
# No. 122 Energy:  12.4 Number of neutron inject 28967.0 efficiency 0.2616536671437753
# No. 123 Energy:  12.5 Number of neutron inject 29125.0 efficiency 0.26292198239739084
# No. 124 Energy:  12.6 Number of neutron inject 28875.0 efficiency 0.2613393909372987
# No. 125 Energy:  12.7 Number of neutron inject 28595.0 efficiency 0.25938987635339544
# No. 126 Energy:  12.8 Number of neutron inject 28272.0 efficiency 0.25606874909846966
# No. 127 Energy:  12.9 Number of neutron inject 28182.0 efficiency 0.25580066505763527
# No. 128 Energy:  13.0 Number of neutron inject 27942.0 efficiency 0.253916434295897
# No. 129 Energy:  13.1 Number of neutron inject 28075.0 efficiency 0.2541486991316415
# No. 130 Energy:  13.2 Number of neutron inject 27922.0 efficiency 0.2531231696940396
# No. 131 Energy:  13.3 Number of neutron inject 27851.0 efficiency 0.2525449306127686
# No. 132 Energy:  13.4 Number of neutron inject 27731.0 efficiency 0.2504652053209741
# No. 133 Energy:  13.5 Number of neutron inject 27698.0 efficiency 0.2508315441505352
# No. 134 Energy:  13.6 Number of neutron inject 27662.0 efficiency 0.25088817148989506
# No. 135 Energy:  13.7 Number of neutron inject 27327.0 efficiency 0.2464322210822933
# No. 136 Energy:  13.8 Number of neutron inject 27721.0 efficiency 0.2507787614834233
# No. 137 Energy:  13.9 Number of neutron inject 27224.0 efficiency 0.24516690146758416
# No. 138 Energy:  14.0 Number of neutron inject 27439.0 efficiency 0.24617706498071812
# No. 139 Energy:  14.1 Number of neutron inject 26962.0 efficiency 0.24187845283332182
# No. 140 Energy:  14.2 Number of neutron inject 26976.0 efficiency 0.24263319980317322
# No. 141 Energy:  14.3 Number of neutron inject 26644.0 efficiency 0.23877673054752274
# No. 142 Energy:  14.4 Number of neutron inject 26713.0 efficiency 0.24059131808134213
# No. 143 Energy:  14.5 Number of neutron inject 26295.0 efficiency 0.23616470690124808
# No. 144 Energy:  14.6 Number of neutron inject 26614.0 efficiency 0.23871787956889404
# No. 145 Energy:  14.7 Number of neutron inject 26333.0 efficiency 0.23567927362635058
# No. 146 Energy:  14.8 Number of neutron inject 26259.0 efficiency 0.23481914564362924
# No. 147 Energy:  14.9 Number of neutron inject 26120.0 efficiency 0.2332834565038362
# No. 148 Energy:  15.0 Number of neutron inject 26015.0 efficiency 0.23182927141254053

# %%
fig = fig_pre_def(10,6,18)
#fig = plt.figure(figsize=(10,6))        # 圖片大小
ax = fig.add_subplot(1, 1, 1)          # 產生1x1格圖片、在第一格

plt.plot([],[],' ',label = 'detection efficiency')
plt.plot(neutron_efficiency_threshold[:,0],neutron_efficiency_threshold[:,1],'.-b',linewidth=2,label='3" EJ-309@1.5m')

fig_post_def(xlim=(0,12),ylim=(0,0.6),xlabel ='Neutron energy (MeV)',ylabel = 'detection efficiency')

# %%
np.savetxt('output/20220211_efficiency.txt',neutron_efficiency_threshold)

# %%
output_pd = pd.DataFrame(Neutron_response)



path = r"output/20220213_3inches_neutron_response_function.xlsx"

book = load_workbook(path)
writer = pd.ExcelWriter(path, engine = 'openpyxl')
writer.book = book

output_pd.to_excel(writer, sheet_name = 'response_function', index=False)

writer.save()
#writer.close()

print("Finished")
# Out:
# Finished

# %%
plt.plot(detected_counts)
